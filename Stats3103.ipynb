# %%
# answer 1:

# A probability density function (PDF) is a mathematical function used in statistics to describe the probability distribution of a continuous random variable. 
# It tells you how likely a random variable is to take on a specific value or fall within a certain range of values.

# %%
# answer 2:
# 1. Normal/gaussian distribution
# 2. bernoulli distribution
# 3. poosson's distribution
# 4. Uniform istribution
# 5. Log normal distribution

# %%
#answer 3:
import math as mt
def pdf(x,Mean, SD) :
    return (1/(SD*mt.sqrt(2*mt.pi)) * 2.72 * ((x-Mean)/(SD)**2))

# %%
#answer 4:
# It is the discrete probability distribution of the numner of success in a sequence of n independent experiments,
# each asking a yes-no question.

# ex-
# tossing a coin for 10 times.
# Out:
#   Cell In[18], line 2
#     It is the discrete probability distribution of the numner of success in a sequence of n independent experiments,
#               ^
# SyntaxError: invalid syntax

# %%
# answer 5:
    
import matplotlib.pyplot as plt
from scipy.stats import binom

# Define parameters for the binomial distribution
n = 1000  # Sample size
p = 0.4  # Probability of success

# Generate random sample
sample = binom.rvs(n, p)

# Create a histogram
plt.hist(sample)
plt.xlabel("Number of successes")
plt.ylabel("Frequency")
plt.title("Histogram of Binomial Distribution (n=1000, p=0.4)")
plt.grid(True)

# Display the plot
plt.show()

# %%
#answer 6:
import math
def ND(Mean, lam):
    return (math.exp(-lam)*(lam**2)/math.factorial(Mean))

# %%
#answer 7:
# Binomial Distribution: Applies to experiments with a fixed number of trials (n).
# Each trial has only two possible outcomes (success or failure), and the trials are independent,
# while,
# Poisson Distribution: Applies to events occurring within a fixed interval of time or space. 
# It assumes a constant average rate (λ) of event occurrences. The number of events itself is not fixed.

# %%
#answer 8:
from scipy.stats import poisson
import statistics as st

mean = 5
n=1000


sample=poisson.rvs(mean,size = 1000)

L = sample.mean()

V = sample.var()

# %%
#answer 9:
#σ^2 = μ * (1 - p) 
#This means that as the mean (number of successes) increases due to a higher number of trials (n) or a higher probability of success (p), the variance also increases proportionally

#answer 10:
# In a normal distribution, the least frequent data appears at the tails, which are the farthest ends of the bell-shaped curve representing the distribution. 
#The data points become progressively less frequent as they move further away from the mean, which is the center of the curve and represents the most frequent value.
